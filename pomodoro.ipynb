# %%
import pandas as pd

# %%
pomodoro = pd.read_csv("pomodoro.csv")
id = pomodoro["id"].iloc[-1]

# %%
id = id + 1
date = "2025-08-11 13:56:00"
learning = """Learned about SELECT, COUNT, DISTINCT and LIMIT statements and WHERE clause. SELECT is a DML (Data manipulation language) that serves to read the data from the database.
           COUNT is an aggregation method to get the total count of the query. DISTINCT is a query to remove all the duplicate values. LIMIT is a query to limit the result to a certain number.
           WHERE clause is used when we want to query the data under certain conditions. We can combine multiple of these statements into one query, for example 
           SELECT COUNT(DISTINCT ReleaseYear) FROM FilmLocations WHERE ProductionCompany = 'Warner Bros. Pictures'; to get the total count of unique release years under the condition that the ProductionCompany is Warner Bros. Pictures
           """
certification = "IBM Data Science"
course = 6
course_name = "Databases and SQL for Data Science with Python"
platform = "Coursera"
total_learning_materials_covered = 8
module = 1
materials_covered = '"Course Introduction"; "Course Overview"; "Introduction to Databases"; "SELECT Statement"; "SELECT statement examples"; "Hands-on Lab: Simple SELECT Statements", "COUNT, DISTINCT, LIMIT"; "Hands-on Lab: COUNT, DISTINCT, LIMIT"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-11 14:31:00"
learning = """Learned about COUNT, DISTINCT and LIMIT statements. Also learned about 2 new DML statements: UPDATE and DELETE. DML statements are used to read and modify data. Be careful, if you don't specify WHERE clauses in UPDATE and DELETE, all of the data will be updated or deleted.
           """
certification = "IBM Data Science"
course = 6
course_name = "Databases and SQL for Data Science with Python"
platform = "Coursera"
total_learning_materials_covered = 4
module = 1
materials_covered = '"Hands-on Lab: COUNT, DISTINCT, LIMIT"; "INSERT Statement"; "UPDATE and DELETE Statements"; "Hands-on Lab: INSERT, UPDATE, and DELETE"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-11 15:08:00"
learning = """Tested my knowledge of DML statements in the practice and graded quiz. Learned about relational database concepts, concepts about primary and foreign keys, where primary keys of a table must be unique to identify each row. Foreign keys are used to connect one table to another table.
           Learned about DDL statements, ALTER, DROP and TRUNCATE. ALTER statement can add or remove columns, modify the data type of columns, add or remove keys and add or remove constraints. DROP will delete the table in the database. TRUNCATE will delete all records of rows in the table, but not the table.
           """
certification = "IBM Data Science"
course = 6
course_name = "Databases and SQL for Data Science with Python"
platform = "Coursera"
total_learning_materials_covered = 8
module = 1, 2
materials_covered = '"Practice Quiz: Basic SQL"; "Graded Quiz: Basic SQL"; "Relational Database Concepts"; "Types of SQL statements (DDL vs. DML)"; "CREATE TABLE Statement"; "ALTER, DROP, and TRUNCATE tables"; "Examples to ALTER and TRUNCATE tables using MySQL"; "Examples to CREATE and DROP tables"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-11 17:00:00"
learning = """Learned about supervised learning. There are 3 types of unsupervised learning that will be covered in this specialization, clustering, anomaly detection and dimensionality reduction.
           Clustering means that, instead of us giving labels for the algorithm to predict, we just give the dataset and let the algorithm find structures in our data. We don't specify labels, or 'supervise' the algorithm
           hence the name is unsupervised learning. One example can be to find customer clusters in an e-commerce's customer dataset. Anomaly detection is used to detect unusual data, particularly useful in finance industry for fraud detection.
           Dimensionality reduction is about reducing the dimensions of the data and losing as little information as possible. Also learned about linear regression. Linear regression is one of the most basic supervised learning algorithm. It is used to predict number outcomes, such as the price of a house.
           There are two types of supervised learning: regression which is to predict infinitely many possible outputs (numbers) and classification which is to predict finite number of possible outputs.
           """
certification = "DeepLearningAI Machine Learning"
course = 1
course_name = "Supervised Machine Learning: Regression and Classification"
platform = "Coursera"
total_learning_materials_covered = 5
module = 1
materials_covered = '"Unsupervised learning part 1"; "Unsupervised learning part 2"; "Jupyter Notebooks"; "Practice quiz: Supervised vs unsupervised learning"; "Linear regression model part 1"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-11 18:04:00"
learning = """Learned about linear regression. This is the formula: f_x = wx + b. w and b are called the parameters (weights or coefficients).
           In linear regression, we try to predict the value by creating a straight line across the dataset in the scatter plot. By the straight line, we can predict new values based on their feature values.
           """
certification = "DeepLearningAI Machine Learning"
course = 1
course_name = "Supervised Machine Learning: Regression and Classification"
platform = "Coursera"
total_learning_materials_covered = 3
module = 1
materials_covered = '"Linear regression model part 2"; "Optional lab: Model representation"; "Cost function formula"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-11 20:56:00"
learning = """Learned about the importance of cost function in linear regression. The best linear regression model is when j of w is equal to 0, or the least possible value.
           """
certification = "DeepLearningAI Machine Learning"
course = 1
course_name = "Supervised Machine Learning: Regression and Classification"
platform = "Coursera"
total_learning_materials_covered = 2
module = 1
materials_covered = '"Cost function intuition"; "Visualizing the cost function"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-12 15:41:00"
learning = """Learned about the importance of cost function. Looked at the visualization of cost function, and how getting the minimum value of cost function will generate the best fit line for regression models.
           Gradient descent is a very important algorithm in machine learning. It is used all across machine learning algorithms. It is used to calculate the minimum cost function when the data gets huge and the models get more complex.
           """
certification = "DeepLearningAI Machine Learning"
course = 1
course_name = "Supervised Machine Learning: Regression and Classification"
platform = "Coursera"
total_learning_materials_covered = 4
module = 1
materials_covered = '"Visualization examples"; "Optional lab: Cost function"; "Practice quiz: Regression"; "Gradient descent"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-12 16:15:00"
learning = """Learned about gradient descent. Gradient descent is about taking steps based on the learning rate to reach the local minimum. If the learning rate is too small, we will get to the local minimum, but might take too many steps to get there.
           If the learning rate is too big, if we are close to the local minimum, we can override the local minimum, and hence increasing the cost, instead of decreasing the cost.
           """
certification = "DeepLearningAI Machine Learning"
course = 1
course_name = "Supervised Machine Learning: Regression and Classification"
platform = "Coursera"
total_learning_materials_covered = 3
module = 1
materials_covered = '"Implementing gradient descent"; "Gradient descent intuition"; "Learning rate"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-12 17:01:00"
learning = """Learned about the connection of cost function and gradient descent for linear regression model. If the learning rate is too small, we will get to the local/global minimum, but will take many steps.
           If the learning rate is too big, we may not get to the local/global minimum and the cost function will diverge, instead of finding the minimum value.
           """
certification = "DeepLearningAI Machine Learning"
course = 1
course_name = "Supervised Machine Learning: Regression and Classification"
platform = "Coursera"
total_learning_materials_covered = 4
module = 1
materials_covered = '"Gradient descent for linear regression"; "Running gradient descent"; "Optional lab: Gradient descent"; "Practice quiz: Train the model with gradient descent"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-12 18:01:00"
learning = """Learned about linear regression with multiple features, where previously, we've only dealt with linear regression with a single feature. Also learned about the importance of vectorization.
           We can do the same thing with vectors, multiplying each individual item to each other, and then summing all of them up with for loop in Python. But there's a much simpler and faster way, that is using numpy dot function.
           With numpy dot function, we can achieve the same result with lesser code in much faster time and probably using less compute power. It's because numpy dot function does the dot product in parallel. It may not be a huge difference with few features, but it can make a lot of difference when we have thousands of features.
           """
certification = "DeepLearningAI Machine Learning"
course = 1
course_name = "Supervised Machine Learning: Regression and Classification"
platform = "Coursera"
total_learning_materials_covered = 3
module = 2
materials_covered = '"Multiple features"; "Vectorization part 1"; "Vectorization part 2"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-13 13:27:00"
learning = """Learned about vectors, matrices and NumPy operations in Python. The dot product is one of the most important function in this course. Using the dot product instead of for loop will significantly improve speed and efficiency, since dot product does parallel calculations.
           Understood a lot more about NumPy shapes, 1-D arrays, 2-D arrays, slicing and their significance.
           """
certification = "DeepLearningAI Machine Learning"
course = 1
course_name = "Supervised Machine Learning: Regression and Classification"
platform = "Coursera"
total_learning_materials_covered = 1
module = 2
materials_covered = '"Optional lab: Python, NumPy and vectorization"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-13 14:07:00"
learning = """Learned about using gradient descent for multiple linear regression. Used the dot product to compute faster and more efficiently. 
           Looked at the code for the prediction, cost computation and gradient descent with multiple variables implementation.
           """
certification = "DeepLearningAI Machine Learning"
course = 1
course_name = "Supervised Machine Learning: Regression and Classification"
platform = "Coursera"
total_learning_materials_covered = 3
module = 2
materials_covered = '"Gradient descent for multiple linear regression", "Optional Lab: Multiple linear regression", "Practice quiz: Multiple linear regression"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-13 17:36:00"
learning = """Learned about the importance of feature scaling. When we have features that have long ranges, it's better to scale the features, so they don't have very large ranges, ideally between -1 and 1, -3 and 3, -0.1 and -.1.
           Just don't let them have long ranges, because it will affect the gradient descent process, it might make the process not converge, or converge longer.
           """
certification = "DeepLearningAI Machine Learning"
course = 1
course_name = "Supervised Machine Learning: Regression and Classification"
platform = "Coursera"
total_learning_materials_covered = 3
module = 2
materials_covered = '"Feature scaling part 1", "Feature scaling part 2", "Checking gradient descent for convergence"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-13 18:11:00"
learning = """Learned about matrices, prediction, cost computing and gradient descent with multiple variables. Also learned about how to choose a good learning rate for gradient descent.
           """
certification = "DeepLearningAI Machine Learning"
course = 1
course_name = "Supervised Machine Learning: Regression and Classification"
platform = "Coursera"
total_learning_materials_covered = 2
module = 2
materials_covered = '"Optional Lab: Multiple linear regression", "Choosing the learning rate"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-14 12:18:00"
learning = """Learned about NumPy broadcasting. Learned about the importance of feature engineering. Learned that not all data can be fit using linear regression, sometimes we need a curve, that's where polynomial regression comes in.
           """
certification = "DeepLearningAI Machine Learning"
course = 1
course_name = "Supervised Machine Learning: Regression and Classification"
platform = "Coursera"
total_learning_materials_covered = 5
module = 2
materials_covered = '"NumPy broadcasting: https://numpy.org/doc/stable/user/basics.broadcasting.html"; "Feature engineering"; "Polynomial regression"; "Optional lab: Feature engineering and Polynomial regression"; "Practice quiz: Gradient descent in practice"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-14 13:25:00"
learning = """Learned about the CREATE, ALTER, TRUNCATE, DROP commands in SQL. Learned that we can import table structures and scripts, instead of typing the SQL scripts manually. We can use .sql files to import table structures and .csv files to import table data.
           """
certification = "IBM Data Science"
course = 6
course_name = "Databases and SQL for Data Science with Python"
platform = "Coursera"
total_learning_materials_covered = 7
module = 2
materials_covered = '"Hands-on Lab: CREATE, ALTER, TRUNCATE, DROP"; "SQL Scripts - Uses and Applications"; "Hands-on Lab: Create and Load Tables using SQL Scripts"; "Summary: Relational Database Concepts and Tables"; "Practice Quiz: Introduction to Relational Databases and Tables"; "Relational DB Concepts and Tables"; "How to create a Database instance on Cloud"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-14 16:56:00"
learning = """Learned about using string patterns and ranges in SQL. If we want to retrieve all rows with strings that start with R, we can do SELECT * FROM table WHERE author LIKE 'R%'. % is a wildcard, which will match anything after the character R.
           We can also use ranges to select values between two values, like SELECT * FROM table WHERE year >= 1990 AND year <= 2000. SELECT * FROM table WHERE year BETWEEN 1990 and 2000. With between, the values are inclusive.
           We can also use the IN keyword if we want to query for many results, such as SELECT * FROM table WHERE country IN ("AU", "US", "ID", "BR").
           We can also sort the table by the column that we want to query. For example, SELECT * FROM table ORDER BY title. will sort the table alphabetically by title. SELECT * FROM table ORDER BY year. will sort the table by its year.
           Learned about grouping result sets using GROUP BY. We can combine GROUP BY with HAVING clause to query the GROUP BY results based on certain conditions. HAVING will only apply to the result of GROUP BY, while WHERE will apply to the result of the whole query.
           SELECT title, COUNT(id) FROM table GROUP BY title HAVING COUNT(id) > 2;
           """
certification = "IBM Data Science"
course = 6
course_name = "Databases and SQL for Data Science with Python"
platform = "Coursera"
total_learning_materials_covered = 5
module = 3
materials_covered = '"Using String Patterns and Ranges"; "Sorting Result Sets"; "Grouping Result Sets"; "Practice Quiz: Refining Your Results"; "Graded Quiz: Refining Your Results"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-14 18:18:00"
learning = """Learned about built-in database functions. There are aggregate built-in functions, such as MAX, MIN, SUM, AVG. MAX gets the maximum value of the aggregated column, MIN gets the minimum, SUM gets the total sum and AVG gets the average value.
           There are also built-in string functions, such as LENGTH, UCASE and LCASE. LENGTH gets the string length of the queried data, UCASE turns the queried data to uppercase and LCASE turns the queried data to lowercase.
           There are also built-in scalar functions, such as ROUND. ROUND will round the queried number to the nearest integer.
           Most databases contain special datatypes for dates and times. Date = YYYYMMDD, time = HHMMSS, timestamp = YYYYXXDDHHMMSSZZZZZZ
           There are also a variety of date functions. We can get the values from a date type data with DAY, MONTH and YEAR. We can also get the date difference with DATE_ADD, DATE_SUB, DATE_DIFF and FROM_DAYS. 
           """
certification = "IBM Data Science"
course = 6
course_name = "Databases and SQL for Data Science with Python"
platform = "Coursera"
total_learning_materials_covered = 3
module = 3
materials_covered = '"Built-in Database Functions"; "Date and Time Built-in Functions"; "Hands-on Lab: Built-in functions"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
id = id + 1
date = "2025-08-14 19:33:00"
learning = """Learned about string patterns, sorting and grouping. Also learned about sub-queries and nested selects. 
           Some aggregate functions can't be used as is, for example SELECT * FROM Employees WHERE Salary < AVG(Salary). This will throw an error.
           Instead, we should use this SELECT * FROM Employees WHERE Salary < (SELECT AVG(Salary) FROM Employees) AS Salary;
           We can also use queries to work with multiple tables. For example, SELECT * FROM Employees, Departments; SELECT * FROM Employees E, Departments D WHERE E.Dep_Id = D.Dep_Id_Dep;
           """
certification = "IBM Data Science"
course = 6
course_name = "Databases and SQL for Data Science with Python"
platform = "Coursera"
total_learning_materials_covered = 4
module = 3
materials_covered = '"Hands-on Lab: String Patterns, Sorting and Grouping"; "Sub-Queries and Nested Selects"; "Hands-on Lab: Sub-queries and Nested Selects"; "Working with Multiple Tables"'
pomodoro = pd.concat([pomodoro, pd.DataFrame({
    "id": [id],
    "time": [date], 
    "learning": [learning], 
    "certification": [certification], 
    "course": [course], 
    "course_name": [course_name],
    "platform": [platform],
    "total_learning_materials_covered": [total_learning_materials_covered],
    "module": [module],
    "materials_covered": [materials_covered]
})], ignore_index=True)

# %%
pomodoro.to_csv("pomodoro_final.csv", index=False)

# %%
pomodoro["time"] = pomodoro["time"].astype(str)
pomodoro["time"] = pomodoro["time"].str.slice(0, 10)
pomodoro.groupby("time").size()
# Out:
# time
# 2025-08-10    7
# 2025-08-11    6
# 2025-08-12    4
# 2025-08-13    4
# 2025-08-14    5
# dtype: int64
